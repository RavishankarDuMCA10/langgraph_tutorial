# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_core.documents.base import Document
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma

embedding_function = OpenAIEmbeddings()

docs = [
    Document(
        page_content="Bella Vista is owned by Antonio Rossi, a renowned chef with over 20 years of experience in the culinary industry. He started Bella Vista to bring authentic Italian flavors to the community.",
        metadata={"source": "owner.txt"},
    ),
    Document(
        page_content="Bella Vista offers a range of dishes with prices that cater to various budgets. Appetizers start at $8, main courses range from $15 to $35, and desserts are priced between $6 and $12.",
        metadata={"source": "dishes.txt"},
    ),
    Document(
        page_content="Bella Vista is open from Monday to Sunday. Weekday hours are 11:00 AM to 10:00 PM, while weekend hours are extended from 11:00 AM to 11:00 PM.",
        metadata={"source": "restaurant_info.txt"},
    ),
    Document(
        page_content="Bella Vista offers a variety of menus including a lunch menu, dinner menu, and a special weekend brunch menu. The lunch menu features light Italian fare, the dinner menu offers a more extensive selection of traditional and contemporary dishes, and the brunch menu includes both classic breakfast items and Italian specialties.",
        metadata={"source": "restaurant_info.txt"},
    ),
]

db = Chroma.from_documents(docs, embedding_function)

# %%
retriever = db.as_retriever(search_kwargs={"k": 4})

# %%
retriever.invoke("When are the opening hours?")
# Out:
# [Document(metadata={'source': 'restaurant_info.txt'}, page_content='Bella Vista is open from Monday to Sunday. Weekday hours are 11:00 AM to 10:00 PM, while weekend hours are extended from 11:00 AM to 11:00 PM.'),
#  Document(metadata={'source': 'restaurant_info.txt'}, page_content='Bella Vista offers a variety of menus including a lunch menu, dinner menu, and a special weekend brunch menu. The lunch menu features light Italian fare, the dinner menu offers a more extensive selection of traditional and contemporary dishes, and the brunch menu includes both classic breakfast items and Italian specialties.'),
#  Document(metadata={'source': 'dishes.txt'}, page_content='Bella Vista offers a range of dishes with prices that cater to various budgets. Appetizers start at $8, main courses range from $15 to $35, and desserts are priced between $6 and $12.'),
#  Document(metadata={'source': 'owner.txt'}, page_content='Bella Vista is owned by Antonio Rossi, a renowned chef with over 20 years of experience in the culinary industry. He started Bella Vista to bring authentic Italian flavors to the community.')]

# %% [markdown]
# ## RAG Prompt

# %%
from langchain_core.prompts import ChatPromptTemplate

template = """Answer the question based only on the following context:
{context}
Question: {question}
"""
prompt = ChatPromptTemplate.from_template(template)

# %%
from langchain_classic import hub

from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI

prompt = hub.pull("rlm/rag-prompt") # use hub to pull RAG-prompt

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

qa_chain = (
    {
        "context": retriever | format_docs,
        "question": RunnablePassthrough(),
    }
    | prompt
    | ChatOpenAI()
    | StrOutputParser()
)

qa_chain.invoke("When are the opening hours?")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 22
#      10     return "\n\n".join(doc.page_content for doc in docs)
#      12 qa_chain = (
#      13     {
#      14         "context": retriever | format_docs,
#    (...)     19     | StrOutputParser()
#      20 )
# ---> 22 qa_chain.invoke("When are the opening hours?")
#
# File ~/Documents/Git Projects/langgraph_tutorial/.venv/lib/python3.13/site-packages/langchain_core/runnables/base.py:3090, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3088                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3089             else:
# -> 3090                 input_ = context.run(step.invoke, input_, config)
#    3091 # finish the root run
#    3092 except BaseException as e:
#
# File ~/Documents/Git Projects/langgraph_tutorial/.venv/lib/python3.13/site-packages/langchain_core/runnables/base.py:4812, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4797 """Invoke this `Runnable` synchronously.
#    4798
#    4799 Args:
#    (...)   4809
#    4810 """
#    4811 if hasattr(self, "func"):
# -> 4812     return self._call_with_config(
#    4813         self._invoke,
#    4814         input,
#    4815         ensure_config(config),
#    4816         **kwargs,
#    4817     )
#    4818 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    4819 raise TypeError(msg)
#
# File ~/Documents/Git Projects/langgraph_tutorial/.venv/lib/python3.13/site-packages/langchain_core/runnables/base.py:2021, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2017     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2018     with set_config_context(child_config) as context:
#    2019         output = cast(
#    2020             "Output",
# -> 2021             context.run(
#    2022                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2023                 func,
#    2024                 input_,
#    2025                 config,
#    2026                 run_manager,
#    2027                 **kwargs,
#    2028             ),
#    2029         )
#    2030 except BaseException as e:
#    2031     run_manager.on_chain_error(e)
#
# File ~/Documents/Git Projects/langgraph_tutorial/.venv/lib/python3.13/site-packages/langchain_core/runnables/config.py:428, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     426 if run_manager is not None and accepts_run_manager(func):
#     427     kwargs["run_manager"] = run_manager
# --> 428 return func(input, **kwargs)
#
# File ~/Documents/Git Projects/langgraph_tutorial/.venv/lib/python3.13/site-packages/langchain_core/runnables/base.py:4669, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4667                 output = chunk
#    4668 else:
# -> 4669     output = call_func_with_variable_args(
#    4670         self.func, input_, config, run_manager, **kwargs
#    4671     )
#    4672 # If the output is a Runnable, invoke it
#    4673 if isinstance(output, Runnable):
#
# File ~/Documents/Git Projects/langgraph_tutorial/.venv/lib/python3.13/site-packages/langchain_core/runnables/config.py:428, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     426 if run_manager is not None and accepts_run_manager(func):
#     427     kwargs["run_manager"] = run_manager
# --> 428 return func(input, **kwargs)
#
# File ~/Documents/Git Projects/langgraph_tutorial/.venv/lib/python3.13/site-packages/langchain_core/load/serializable.py:113, in Serializable.__init__(self, *args, **kwargs)
#     111 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     112     """"""  # noqa: D419  # Intentional blank docstring
# --> 113     super().__init__(*args, **kwargs)
#
# TypeError: BaseModel.__init__() takes 1 positional argument but 2 were given
